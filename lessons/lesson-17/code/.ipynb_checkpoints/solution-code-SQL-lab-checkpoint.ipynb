# %% [markdown]
# # SQL Lab
#
# In this lab we will learn how to use execute SQL from the ipython notebook and practice some queries on the [Northwind sample database](https://northwinddatabase.codeplex.com/) that we used in Lesson 3.1.
#
# You can access the data with this command:
#
#     psql -h dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com -p 5432 -U dsi_student northwind
#     password: gastudents

# %% [markdown]
# First of all let's install the ipython-sql extension. You can find instructions [here](https://github.com/catherinedevlin/ipython-sql).

# %%
# !pip install ipython-sql

# %% [markdown]
# Let's see if it works:

# %%
# %load_ext sql

# %%
# %%sql postgresql://dsi_student:gastudents@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
#
# select * from orders limit 5;
# Out:
# /Users/dat-44pt/miniconda3/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# 5 rows affected.
# [(10248, 'VINET', 5, datetime.date(1996, 7, 4), datetime.date(1996, 8, 1), datetime.date(1996, 7, 16), 3, 32.38, 'Vins et alcools Chevalier', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France'),
#  (10249, 'TOMSP', 6, datetime.date(1996, 7, 5), datetime.date(1996, 8, 16), datetime.date(1996, 7, 10), 1, 11.61, 'Toms Spezialitäten', 'Luisenstr. 48', 'Münster', None, '44087', 'Germany'),
#  (10250, 'HANAR', 4, datetime.date(1996, 7, 8), datetime.date(1996, 8, 5), datetime.date(1996, 7, 12), 2, 65.83, 'Hanari Carnes', 'Rua do Paço, 67', 'Rio de Janeiro', 'RJ', '05454-876', 'Brazil'),
#  (10251, 'VICTE', 3, datetime.date(1996, 7, 8), datetime.date(1996, 8, 5), datetime.date(1996, 7, 15), 1, 41.34, 'Victuailles en stock', '2, rue du Commerce', 'Lyon', None, '69004', 'France'),
#  (10252, 'SUPRD', 4, datetime.date(1996, 7, 9), datetime.date(1996, 8, 6), datetime.date(1996, 7, 11), 2, 51.3, 'Suprêmes délices', 'Boulevard Tirou, 255', 'Charleroi', None, 'B-6000', 'Belgium')]

# %% [markdown]
# Nice!!! We can now go ahead with the lab!

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1: Inspect the Database
#
# If we were connected via console, it would be easy to list all tables using `\dt`. We can however access table information performing a query on the `information_schema.tables` table.
#
# ### 1.a: List Tables
#
# 1. Write a `SELECT` statement that lists all the tables in the public schema of the `northwind` database, sorted alphabetically.

# %%
# %%sql
# SELECT table_schema,table_name
# FROM information_schema.tables
# WHERE table_schema = 'public'
# ORDER BY table_name;
# Out:
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 64 rows affected.
# [('public', 'categories'),
#  ('public', 'categoriesmerged'),
#  ('public', 'categories_pd'),
#  ('public', 'credit_card_feature'),
#  ('public', 'customercustomerdemo'),
#  ('public', 'customerdemographics'),
#  ('public', 'customers'),
#  ('public', 'descriptions'),
#  ('public', 'descriptions1'),
#  ('public', 'descriptions2'),
#  ('public', 'employees'),
#  ('public', 'employeeterritories'),
#  ('public', 'empterid'),
#  ('public', 'empterid2'),
#  ('public', 'final'),
#  ('public', 'final2'),
#  ('public', 'final3'),
#  ('public', 'final4'),
#  ('public', 'final5'),
#  ('public', 'fo'),
#  ('public', 'full_ord'),
#  ('public', 'full_order'),
#  ('public', 'fullorders'),
#  ('public', 'full_orders_'),
#  ('public', 'fullorders_'),
#  ('public', 'fullorders__'),
#  ('public', 'full_order_table'),
#  ('public', 'full_order_table2'),
#  ('public', 'full_order_table3'),
#  ('public', 'full_order_table4'),
#  ('public', 'full_order_table5'),
#  ('public', 'google_app'),
#  ('public', 'movies'),
#  ('public', 'my_table'),
#  ('public', 'newregion'),
#  ('public', 'new_table'),
#  ('public', 'order_details'),
#  ('public', 'order_details_temp'),
#  ('public', 'orders'),
#  ('public', 'order_table'),
#  ('public', 'payments'),
#  ('public', 'pindor'),
#  ('public', 'price'),
#  ('public', 'price2'),
#  ('public', 'products'),
#  ('public', 'ratings'),
#  ('public', 'region'),
#  ('public', 'sessions'),
#  ('public', 'shippers'),
#  ('public', 'shippers_tmp'),
#  ('public', 'ship_secrets'),
#  ('public', 'student_practice'),
#  ('public', 'students'),
#  ('public', 'subscriptions'),
#  ('public', 'suppliers'),
#  ('public', 'table1'),
#  ('public', 'table_join'),
#  ('public', 'temp_table'),
#  ('public', 'territories'),
#  ('public', 'top_5'),
#  ('public', 'updatdregion'),
#  ('public', 'updatedregion'),
#  ('public', 'updatedregion1'),
#  ('public', 'usstates')]

# %% [markdown]
# ### 1.b: Print Schemas
#
# The table `INFORMATION_SCHEMA.COLUMNS` contains schema information on each.
#
# Query it to display schemas of all the public tables. In particular we are interested in the column names and data types. Make sure you only include public schemas to avoid cluttering your results with a bunch of postgres related stuff.

# %%
# %%sql
# SELECT table_name, column_name, data_type
# FROM INFORMATION_SCHEMA.COLUMNS
# WHERE table_catalog = 'northwind'
# and table_schema = 'public';
# Out:
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 340 rows affected.
# [('categories', 'CategoryID', 'smallint'),
#  ('categories', 'CategoryName', 'character varying'),
#  ('categories', 'Description', 'text'),
#  ('categories', 'Picture', 'bytea'),
#  ('full_order_table5', 'ProductID', 'smallint'),
#  ('full_order_table5', 'UnitPrice', 'real'),
#  ('full_order_table5', 'OrderID', 'smallint'),
#  ('full_order_table5', 'EmployeeID', 'smallint'),
#  ('full_order_table5', 'TerritoryDescription', 'character'),
#  ('full_order_table5', 'RegionDescription', 'character'),
#  ('fo', 'ProductID', 'smallint'),
#  ('fo', 'UnitPrice', 'real'),
#  ('fo', 'OrderID', 'smallint'),
#  ('fo', 'EmployeeID', 'smallint'),
#  ('fo', 'TerritoryDescription', 'character'),
#  ('fo', 'RegionDescription', 'character'),
#  ('table_join', 'EmployeeID', 'smallint'),
#  ('table_join', 'RegionDescription', 'character'),
#  ('table_join', 'TerritoryDescription', 'character'),
#  ('table_join', 'OrderID', 'smallint'),
#  ('table_join', 'ProductID', 'smallint'),
#  ('table_join', 'UnitPrice', 'real'),
#  ('full_order', 'EmployeeID', 'smallint'),
#  ('full_order', 'TerritoryDescription', 'character'),
#  ('full_order', 'RegionDescription', 'character'),
#  ('full_order', 'OrderID', 'smallint'),
#  ('full_order', 'ProductID', 'smallint'),
#  ('full_order', 'UnitPrice', 'real'),
#  ('full_order', 'Quantity', 'smallint'),
#  ('customercustomerdemo', 'CustomerID', 'character'),
#  ('customercustomerdemo', 'CustomerTypeID', 'character'),
#  ('customerdemographics', 'CustomerTypeID', 'character'),
#  ('customerdemographics', 'CustomerDesc', 'text'),
#  ('customers', 'CustomerID', 'character'),
#  ('customers', 'CompanyName', 'character varying'),
#  ('customers', 'ContactName', 'character varying'),
#  ('customers', 'ContactTitle', 'character varying'),
#  ('customers', 'Address', 'character varying'),
#  ('customers', 'City', 'character varying'),
#  ('customers', 'Region', 'character varying'),
#  ('customers', 'PostalCode', 'character varying'),
#  ('customers', 'Country', 'character varying'),
#  ('customers', 'Phone', 'character varying'),
#  ('customers', 'Fax', 'character varying'),
#  ('employees', 'EmployeeID', 'smallint'),
#  ('employees', 'LastName', 'character varying'),
#  ('employees', 'FirstName', 'character varying'),
#  ('employees', 'Title', 'character varying'),
#  ('employees', 'TitleOfCourtesy', 'character varying'),
#  ('employees', 'BirthDate', 'date'),
#  ('employees', 'HireDate', 'date'),
#  ('employees', 'Address', 'character varying'),
#  ('employees', 'City', 'character varying'),
#  ('employees', 'Region', 'character varying'),
#  ('employees', 'PostalCode', 'character varying'),
#  ('employees', 'Country', 'character varying'),
#  ('employees', 'HomePhone', 'character varying'),
#  ('employees', 'Extension', 'character varying'),
#  ('employees', 'Photo', 'bytea'),
#  ('employees', 'Notes', 'text'),
#  ('employees', 'ReportsTo', 'smallint'),
#  ('employees', 'PhotoPath', 'character varying'),
#  ('employeeterritories', 'EmployeeID', 'smallint'),
#  ('employeeterritories', 'TerritoryID', 'character varying'),
#  ('order_details', 'OrderID', 'smallint'),
#  ('order_details', 'ProductID', 'smallint'),
#  ('order_details', 'UnitPrice', 'real'),
#  ('order_details', 'Quantity', 'smallint'),
#  ('order_details', 'Discount', 'real'),
#  ('orders', 'OrderID', 'smallint'),
#  ('orders', 'CustomerID', 'character'),
#  ('orders', 'EmployeeID', 'smallint'),
#  ('orders', 'OrderDate', 'date'),
#  ('orders', 'RequiredDate', 'date'),
#  ('orders', 'ShippedDate', 'date'),
#  ('orders', 'ShipVia', 'smallint'),
#  ('orders', 'Freight', 'real'),
#  ('orders', 'ShipName', 'character varying'),
#  ('orders', 'ShipAddress', 'character varying'),
#  ('orders', 'ShipCity', 'character varying'),
#  ('orders', 'ShipRegion', 'character varying'),
#  ('orders', 'ShipPostalCode', 'character varying'),
#  ('orders', 'ShipCountry', 'character varying'),
#  ('products', 'ProductID', 'smallint'),
#  ('products', 'ProductName', 'character varying'),
#  ('products', 'SupplierID', 'smallint'),
#  ('products', 'CategoryID', 'smallint'),
#  ('products', 'QuantityPerUnit', 'character varying'),
#  ('products', 'UnitPrice', 'real'),
#  ('products', 'UnitsInStock', 'smallint'),
#  ('products', 'UnitsOnOrder', 'smallint'),
#  ('products', 'ReorderLevel', 'smallint'),
#  ('products', 'Discontinued', 'integer'),
#  ('region', 'RegionID', 'smallint'),
#  ('region', 'RegionDescription', 'character'),
#  ('shippers', 'ShipperID', 'smallint'),
#  ('shippers', 'CompanyName', 'character varying'),
#  ('shippers', 'Phone', 'character varying'),
#  ('shippers_tmp', 'ShipperID', 'smallint'),
#  ('shippers_tmp', 'CompanyName', 'character varying'),
#  ('shippers_tmp', 'Phone', 'character varying'),
#  ('suppliers', 'SupplierID', 'smallint'),
#  ('suppliers', 'CompanyName', 'character varying'),
#  ('suppliers', 'ContactName', 'character varying'),
#  ('suppliers', 'ContactTitle', 'character varying'),
#  ('suppliers', 'Address', 'character varying'),
#  ('suppliers', 'City', 'character varying'),
#  ('suppliers', 'Region', 'character varying'),
#  ('suppliers', 'PostalCode', 'character varying'),
#  ('suppliers', 'Country', 'character varying'),
#  ('suppliers', 'Phone', 'character varying'),
#  ('suppliers', 'Fax', 'character varying'),
#  ('suppliers', 'HomePage', 'text'),
#  ('territories', 'TerritoryID', 'character varying'),
#  ('territories', 'TerritoryDescription', 'character'),
#  ('territories', 'RegionID', 'smallint'),
#  ('usstates', 'StateID', 'smallint'),
#  ('usstates', 'StateName', 'character varying'),
#  ('usstates', 'StateAbbr', 'character varying'),
#  ('usstates', 'StateRegion', 'character varying'),
#  ('table1', 'num_votes', 'character varying'),
#  ('table1', 'rating', 'character varying'),
#  ('table1', 'tconst', 'character'),
#  ('table1', 'title', 'character'),
#  ('table1', 'year', 'character varying'),
#  ('table1', 'genre', 'character'),
#  ('table1', 'runtime', 'character varying'),
#  ('movies', 'index', 'bigint'),
#  ('movies', 'num_votes', 'bigint'),
#  ('movies', 'rating', 'double precision'),
#  ('movies', 'tconst', 'text'),
#  ('movies', 'title', 'text'),
#  ('movies', 'year', 'text'),
#  ('movies', 'genre', 'text'),
#  ('movies', 'runtime', 'double precision'),
#  ('ratings', 'index', 'bigint'),
#  ('ratings', '0', 'text'),
#  ('ratings', 'ratings', 'text'),
#  ('ratings', 'movie', 'text'),
#  ('categoriesmerged', 'index', 'bigint'),
#  ('categoriesmerged', 'ProductID', 'bigint'),
#  ('categoriesmerged', 'ProductName', 'text'),
#  ('categoriesmerged', 'SupplierID', 'bigint'),
#  ('categoriesmerged', 'CategoryID', 'bigint'),
#  ('categoriesmerged', 'QuantityPerUnit', 'text'),
#  ('categoriesmerged', 'UnitPrice', 'double precision'),
#  ('categoriesmerged', 'UnitsInStock', 'bigint'),
#  ('categoriesmerged', 'UnitsOnOrder', 'bigint'),
#  ('categoriesmerged', 'ReorderLevel', 'bigint'),
#  ('categoriesmerged', 'Discontinued', 'bigint'),
#  ('categoriesmerged', 'CategoryName', 'text'),
#  ('categoriesmerged', 'Description', 'text'),
#  ('categoriesmerged', 'Picture', 'text'),
#  ('order_table', 'EmployeeID', 'smallint'),
#  ('order_table', 'RegionDescription', 'character'),
#  ('order_table', 'TerritoryDescription', 'character'),
#  ('order_table', 'OrderID', 'smallint'),
#  ('order_table', 'ProductID', 'smallint'),
#  ('order_table', 'UnitPrice', 'real'),
#  ('full_ord', 'ProductID', 'smallint'),
#  ('full_ord', 'UnitPrice', 'real'),
#  ('full_ord', 'Quantity', 'smallint'),
#  ('full_ord', 'OrderID', 'smallint'),
#  ('full_ord', 'EmployeeID', 'smallint'),
#  ('full_ord', 'TerritoryDescription', 'character'),
#  ('full_ord', 'RegionDescription', 'character'),
#  ('new_table', 'OrderID', 'smallint'),
#  ('new_table', 'EmployeeID', 'smallint'),
#  ('new_table', 'ProductID', 'smallint'),
#  ('new_table', 'UnitPrice', 'real'),
#  ('new_table', 'TerritoryDescription', 'character'),
#  ('new_table', 'RegionDescription', 'character'),
#  ('full_order_table', 'OrderID', 'smallint'),
#  ('full_order_table', 'EmployeeID', 'smallint'),
#  ('full_order_table', 'ProductID', 'smallint'),
#  ('full_order_table', 'UnitPrice', 'real'),
#  ('full_order_table', 'TerritoryDescription', 'character'),
#  ('full_order_table', 'RegionDescription', 'character'),
#  ('full_order_table2', 'OrderID', 'smallint'),
#  ('full_order_table2', 'EmployeeID', 'smallint'),
#  ('full_order_table2', 'ProductID', 'smallint'),
#  ('full_order_table2', 'UnitPrice', 'real'),
#  ('full_order_table2', 'TerritoryDescription', 'character'),
#  ('full_order_table2', 'RegionDescription', 'character'),
#  ('full_order_table3', 'OrderID', 'smallint'),
#  ('full_order_table3', 'EmployeeID', 'smallint'),
#  ('full_order_table3', 'ProductID', 'smallint'),
#  ('full_order_table3', 'UnitPrice', 'real'),
#  ('full_order_table3', 'TerritoryDescription', 'character'),
#  ('full_order_table3', 'RegionDescription', 'character'),
#  ('full_order_table4', 'ProductID', 'smallint'),
#  ('full_order_table4', 'UnitPrice', 'real'),
#  ('full_order_table4', 'OrderID', 'smallint'),
#  ('full_order_table4', 'EmployeeID', 'smallint'),
#  ('full_order_table4', 'TerritoryDescription', 'character'),
#  ('full_order_table4', 'RegionDescription', 'character'),
#  ('temp_table', 'EmployeeID', 'smallint'),
#  ('temp_table', 'FirstName', 'character varying'),
#  ('temp_table', 'LastName', 'character varying'),
#  ('temp_table', 'RegionDescription', 'character'),
#  ('temp_table', 'TerritoryDescription', 'character'),
#  ('temp_table', 'OrderID', 'smallint'),
#  ('temp_table', 'ProductID', 'smallint'),
#  ('temp_table', 'total_sales', 'double precision'),
#  ('full_orders_', 'EmployeeID', 'smallint'),
#  ('full_orders_', 'RegionDescription', 'character'),
#  ('full_orders_', 'TerritoryDescription', 'character'),
#  ('full_orders_', 'OrderID', 'smallint'),
#  ('full_orders_', 'ProductID', 'smallint'),
#  ('full_orders_', 'UnitPrice', 'real'),
#  ('full_orders_', 'Quantity', 'smallint'),
#  ('fullorders_', 'EmployeeID', 'smallint'),
#  ('fullorders_', 'RegionDescription', 'character'),
#  ('fullorders_', 'TerritoryDescription', 'character'),
#  ('fullorders_', 'OrderID', 'smallint'),
#  ('fullorders_', 'ProductID', 'smallint'),
#  ('fullorders_', 'UnitPrice', 'real'),
#  ('fullorders_', 'Quantity', 'smallint'),
#  ('fullorders__', 'EmployeeID', 'smallint'),
#  ('fullorders__', 'RegionDescription', 'character'),
#  ('fullorders__', 'TerritoryDescription', 'character'),
#  ('fullorders__', 'OrderID', 'smallint'),
#  ('fullorders__', 'ProductID', 'smallint'),
#  ('fullorders__', 'UnitPrice', 'real'),
#  ('fullorders__', 'Quantity', 'smallint'),
#  ('fullorders', 'EmployeeID', 'smallint'),
#  ('fullorders', 'RegionDescription', 'character'),
#  ('fullorders', 'TerritoryDescription', 'character'),
#  ('fullorders', 'OrderID', 'smallint'),
#  ('fullorders', 'ProductID', 'smallint'),
#  ('fullorders', 'UnitPrice', 'real'),
#  ('fullorders', 'Quantity', 'smallint'),
#  ('descriptions', 'RegionDescription', 'character'),
#  ('descriptions', 'TerritoryDescription', 'character'),
#  ('descriptions', 'TerritoryID', 'character varying'),
#  ('price', 'OrderID', 'smallint'),
#  ('price', 'EmployeeID', 'smallint'),
#  ('price', 'ProductID', 'smallint'),
#  ('price', 'UnitPrice', 'real'),
#  ('descriptions1', 'RegionDescription', 'character'),
#  ('descriptions1', 'TerritoryDescription', 'character'),
#  ('descriptions1', 'TerritoryID', 'character varying'),
#  ('empterid', 'EmployeeID', 'smallint'),
#  ('empterid', 'TerritoryID', 'character varying'),
#  ('google_app', 'app_id', 'integer'),
#  ('google_app', 'user_id', 'integer'),
#  ('google_app', 'event', 'character varying'),
#  ('google_app', 'timestamp', 'integer'),
#  ('final', 'EmployeeID', 'smallint'),
#  ('final', 'TerritoryID', 'character varying'),
#  ('final', 'RegionDescription', 'character'),
#  ('final', 'TerritoryDescription', 'character'),
#  ('final', 'OrderID', 'smallint'),
#  ('final', 'ProductID', 'smallint'),
#  ('final', 'UnitPrice', 'real'),
#  ('final2', 'EmployeeID', 'smallint'),
#  ('final2', 'TerritoryID', 'character varying'),
#  ('final2', 'RegionDescription', 'character'),
#  ('final2', 'TerritoryDescription', 'character'),
#  ('final2', 'OrderID', 'smallint'),
#  ('final2', 'ProductID', 'smallint'),
#  ('final2', 'UnitPrice', 'real'),
#  ('final3', 'EmployeeID', 'smallint'),
#  ('final3', 'RegionDescription', 'character'),
#  ('final3', 'TerritoryDescription', 'character'),
#  ('final3', 'OrderID', 'smallint'),
#  ('final3', 'ProductID', 'smallint'),
#  ('final3', 'UnitPrice', 'real'),
#  ('final4', 'EmployeeID', 'smallint'),
#  ('final4', 'RegionDescription', 'character'),
#  ('final4', 'TerritoryDescription', 'character'),
#  ('final4', 'OrderID', 'smallint'),
#  ('final4', 'ProductID', 'smallint'),
#  ('final4', 'UnitPrice', 'real'),
#  ('credit_card_feature', 'app_id', 'integer'),
#  ('credit_card_feature', 'user_id', 'integer'),
#  ('credit_card_feature', 'event', 'character varying'),
#  ('credit_card_feature', 'timestamp', 'bigint'),
#  ('price2', 'OrderID', 'smallint'),
#  ('price2', 'EmployeeID', 'smallint'),
#  ('price2', 'ProductID', 'smallint'),
#  ('price2', 'UnitPrice', 'real'),
#  ('descriptions2', 'RegionDescription', 'character'),
#  ('descriptions2', 'TerritoryDescription', 'character'),
#  ('descriptions2', 'TerritoryID', 'character varying'),
#  ('empterid2', 'EmployeeID', 'smallint'),
#  ('empterid2', 'TerritoryID', 'character varying'),
#  ('final5', 'EmployeeID', 'smallint'),
#  ('final5', 'RegionDescription', 'character'),
#  ('final5', 'TerritoryDescription', 'character'),
#  ('final5', 'OrderID', 'smallint'),
#  ('final5', 'ProductID', 'smallint'),
#  ('final5', 'UnitPrice', 'real'),
#  ('my_table', 'TerritoryDescription', 'character'),
#  ('my_table', 'RegionID', 'smallint'),
#  ('my_table', 'EmployeeID', 'smallint'),
#  ('my_table', 'OrderID', 'smallint'),
#  ('my_table', 'ProductID', 'smallint'),
#  ('my_table', 'UnitPrice', 'real'),
#  ('my_table', 'RegionDescription', 'character'),
#  ('newregion', 'PersonID', 'integer'),
#  ('newregion', 'RegionDescription', 'character varying'),
#  ('updatdregion', 'ID', 'integer'),
#  ('updatdregion', 'RegionDescription', 'character varying'),
#  ('updatedregion', 'ID', 'integer'),
#  ('updatedregion', 'RegionDescription', 'character varying'),
#  ('updatedregion1', 'RegionID', 'integer'),
#  ('updatedregion1', 'RegionDescription', 'character varying'),
#  ('ship_secrets', 'ShipName', 'character varying'),
#  ('ship_secrets', 'ShipCountry', 'character varying'),
#  ('ship_secrets', 'ShipPostalCode', 'character varying'),
#  ('top_5', 'top_5_pct', 'double precision'),
#  ('sessions', 'id', 'integer'),
#  ('sessions', 'userid', 'integer'),
#  ('sessions', 'duration', 'numeric'),
#  ('subscriptions', 'subscription_id', 'integer'),
#  ('subscriptions', 'subscription_type', 'integer'),
#  ('subscriptions', 'status', 'integer'),
#  ('subscriptions', 'num_students_allowed', 'integer'),
#  ('payments', 'payment_id', 'integer'),
#  ('payments', 'subscription_id', 'integer'),
#  ('payments', 'payment_date', 'date'),
#  ('payments', 'payment_amount', 'integer'),
#  ('students', 'student_id', 'integer'),
#  ('students', 'subscription_id', 'integer'),
#  ('students', 'username', 'character varying'),
#  ('student_practice', 'student_id', 'integer'),
#  ('student_practice', 'practice_date', 'date'),
#  ('order_details_temp', 'OrderID', 'smallint'),
#  ('order_details_temp', 'ProductID', 'smallint'),
#  ('order_details_temp', 'UnitPrice', 'real'),
#  ('order_details_temp', 'Quantity', 'smallint'),
#  ('order_details_temp', 'Discount', 'real'),
#  ('categories_pd', 'index', 'bigint'),
#  ('categories_pd', 'CategoryID', 'bigint'),
#  ('categories_pd', 'CategoryName', 'text'),
#  ('categories_pd', 'Description', 'text'),
#  ('categories_pd', 'Picture', 'text'),
#  ('pindor', 'profesor', 'character varying'),
#  ('pindor', 'legajo', 'integer')]

# %% [markdown]
# ### 1.c Table peek
#
# Another way of quickly looking at table information is to query the first few rows. Do this for a couple of tables, for example: `orders`, `products`, `usstates`. Display only the first 3 rows.

# %%
# %%sql
# SELECT * FROM orders LIMIT 3;
# Out:
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 3 rows affected.
# [(10248, 'VINET', 5, datetime.date(1996, 7, 4), datetime.date(1996, 8, 1), datetime.date(1996, 7, 16), 3, 32.38, 'Vins et alcools Chevalier', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France'),
#  (10249, 'TOMSP', 6, datetime.date(1996, 7, 5), datetime.date(1996, 8, 16), datetime.date(1996, 7, 10), 1, 11.61, 'Toms Spezialitäten', 'Luisenstr. 48', 'Münster', None, '44087', 'Germany'),
#  (10250, 'HANAR', 4, datetime.date(1996, 7, 8), datetime.date(1996, 8, 5), datetime.date(1996, 7, 12), 2, 65.83, 'Hanari Carnes', 'Rua do Paço, 67', 'Rio de Janeiro', 'RJ', '05454-876', 'Brazil')]

# %%
# %%sql
# SELECT * FROM products LIMIT 3;
# Out:
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 3 rows affected.
# [(1, 'Chai', 8, 1, '10 boxes x 30 bags', 18.0, 39, 0, 10, 1),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19.0, 17, 40, 25, 1),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10.0, 13, 70, 25, 0)]

# %%
# %%sql
# SELECT * FROM usstates LIMIT 3;
# Out:
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 3 rows affected.
# [(1, 'Alabama', 'AL', 'south'),
#  (2, 'Alaska', 'AK', 'north'),
#  (3, 'Arizona', 'AZ', 'west')]

# %% [markdown]
# As you can see, some tables (like `usstates` or `region`) contain information that is probably less prone to change than other tables (like `orders` or `order_details`). This database is well organized to avoid unnecessary duplication. Let's start digging deeper in the data.

# %% [markdown]
# ## 2: Products
#
# What products is this company selling? The `products` and `categories` tables contain information to answer this question.
#
# Use a combination of SQL queries and Pandas merge to answer the following questions:
#
# - What categories of products is the company selling?
# - How many products per category does the catalog contain?
# - Let's focus only on products that have not been discontinued => how many products per category?
# - What are the most expensive 5 products (not discontinued)?
# - How many units of each of these 5 products are there in stock?
# - Draw a pie chart of the categories, with slices that have the size of the number of products in that category (use non discontinued products).

# %% [markdown]
# ### 2.a: What categories of products is the company selling?
#
# Remember that PostgreSQL is case sensitive.

# %%
categories = %sql SELECT "CategoryID", "CategoryName", "Description" FROM categories;
categories
# Out:
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 8 rows affected.
# [(1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (3, 'Confections', 'Desserts, candies, and sweet breads'),
#  (4, 'Dairy Products', 'Cheeses'),
#  (5, 'Grains/Cereals', 'Breads, crackers, pasta, and cereal'),
#  (6, 'Meat/Poultry', 'Prepared meats'),
#  (7, 'Produce', 'Dried fruit and bean curd'),
#  (8, 'Seafood', 'Seaweed and fish')]

# %% [markdown]
# ### 2.b: How many products per category does the catalog contain?
#
# Keep in mind that you can cast a %sql result to a pandas dataframe using the `.DataFrame()` method.

# %%
category_counts = %sql SELECT "CategoryID", count(*) AS count\
                    FROM  products \
                    GROUP BY "CategoryID" \
                    ORDER BY count desc;
category_counts
# Out:
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 8 rows affected.
# [(3, 13), (8, 12), (1, 12), (2, 12), (4, 10), (5, 7), (6, 6), (7, 5)]

# %%
pd.merge(category_counts.DataFrame(), categories.DataFrame())
# Out:
#    CategoryID  count    CategoryName  \
# 0           3     13     Confections
# 1           8     12         Seafood
# 2           1     12       Beverages
# 3           2     12      Condiments
# 4           4     10  Dairy Products
# 5           5      7  Grains/Cereals
# 6           6      6    Meat/Poultry
# 7           7      5         Produce
#
#                                          Description
# 0                Desserts, candies, and sweet breads
# 1                                   Seaweed and fish
# 2        Soft drinks, coffees, teas, beers, and ales
# 3  Sweet and savory sauces, relishes, spreads, an...
# 4                                            Cheeses
# 5                Breads, crackers, pasta, and cereal
# 6                                     Prepared meats
# 7                          Dried fruit and bean curd

# %% [markdown]
# ### 2.c: How many not discontinued products per category?

# %%
# %%sql
# SELECT "CategoryID", count(*) AS count
# FROM  products
# WHERE "Discontinued" = 0
# GROUP BY "CategoryID"
# ORDER BY count desc;
# Out:
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 8 rows affected.
# [(3, 13), (8, 12), (2, 11), (4, 10), (1, 9), (5, 6), (7, 4), (6, 2)]

# %%
category_counts_not_disc = _

# %%
products_per_category = pd.merge(category_counts_not_disc.DataFrame(), categories.DataFrame())
products_per_category
# Out:
#    CategoryID  count    CategoryName  \
# 0           3     13     Confections
# 1           8     12         Seafood
# 2           2     11      Condiments
# 3           4     10  Dairy Products
# 4           1      9       Beverages
# 5           5      6  Grains/Cereals
# 6           7      4         Produce
# 7           6      2    Meat/Poultry
#
#                                          Description
# 0                Desserts, candies, and sweet breads
# 1                                   Seaweed and fish
# 2  Sweet and savory sauces, relishes, spreads, an...
# 3                                            Cheeses
# 4        Soft drinks, coffees, teas, beers, and ales
# 5                Breads, crackers, pasta, and cereal
# 6                          Dried fruit and bean curd
# 7                                     Prepared meats

# %% [markdown]
# ### 2.d: What are the most expensive 5 products (not discontinued)?

# %%
# %%sql
# SELECT * from products
# WHERE "Discontinued" = 0
# ORDER BY "UnitPrice" desc
# LIMIT 5;
# Out:
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 5 rows affected.
# [(38, 'Côte de Blaye', 18, 1, '12 - 75 cl bottles', 263.5, 17, 0, 15, 0),
#  (20, "Sir Rodney's Marmalade", 8, 3, '30 gift boxes', 81.0, 40, 0, 0, 0),
#  (18, 'Carnarvon Tigers', 7, 8, '16 kg pkg.', 62.5, 42, 0, 0, 0),
#  (59, 'Raclette Courdavault', 28, 4, '5 kg pkg.', 55.0, 79, 0, 0, 0),
#  (51, 'Manjimup Dried Apples', 24, 7, '50 - 300 g pkgs.', 53.0, 20, 0, 10, 0)]

# %% [markdown]
# ### 2.e: How many units of each of these 5 products are there in stock?

# %%
# see above

# %% [markdown]
# ### 2.f: Pie Chart
#
# Use pandas to make a pie chart plot.

# %%
products_per_category[['CategoryName', 'count']].set_index('CategoryName').plot(kind = 'pie',
                                                                                y = 'count',
                                                                                figsize = (10,10))
plt.legend(loc = 2);

# %% [markdown]
# ## 3: Orders
#
# Now that we have a better understanding of products, let's start digging into orders.
#
# - How many orders in total?
# - How many orders per year
# - How many orders per quarter
# - Which country is receiving the most orders
# - Which country is receiving the least
# - What's the average shipping time (ShippedDate - OrderDate)
# - What customer is submitting the highest number of orders?
# - What customer is generating the highest revenue (need to pd.merge with order_details)
# - What fraction of the revenue is generated by the top 5 customers?

# %%
# %%sql
# SELECT * FROM orders LIMIT 3;
# Out:
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 3 rows affected.
# [(10248, 'VINET', 5, datetime.date(1996, 7, 4), datetime.date(1996, 8, 1), datetime.date(1996, 7, 16), 3, 32.38, 'Vins et alcools Chevalier', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France'),
#  (10249, 'TOMSP', 6, datetime.date(1996, 7, 5), datetime.date(1996, 8, 16), datetime.date(1996, 7, 10), 1, 11.61, 'Toms Spezialitäten', 'Luisenstr. 48', 'Münster', None, '44087', 'Germany'),
#  (10250, 'HANAR', 4, datetime.date(1996, 7, 8), datetime.date(1996, 8, 5), datetime.date(1996, 7, 12), 2, 65.83, 'Hanari Carnes', 'Rua do Paço, 67', 'Rio de Janeiro', 'RJ', '05454-876', 'Brazil')]

# %% [markdown]
# ### 3.a: How many orders in total?

# %%
# %%sql
# SELECT count(*) FROM orders;
# Out:
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 1 rows affected.
# [(830,)]

# %% [markdown]
# ### 3.b: How many orders per year?

# %%
order_dates = %sql SELECT "OrderID", "OrderDate" FROM orders;
order_dates = order_dates.DataFrame()
order_dates.index = pd.to_datetime(order_dates['OrderDate'])
order_dates.head()
# Out:
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 830 rows affected.
#             OrderID   OrderDate
# OrderDate
# 1996-07-04    10248  1996-07-04
# 1996-07-05    10249  1996-07-05
# 1996-07-08    10250  1996-07-08
# 1996-07-08    10251  1996-07-08
# 1996-07-09    10252  1996-07-09

# %%
orders_per_year = order_dates.groupby(pd.Grouper(freq='A'))['OrderID'].count()
orders_per_year
# Out:
# OrderDate
# 1996-12-31    152
# 1997-12-31    408
# 1998-12-31    270
# Freq: A-DEC, Name: OrderID, dtype: int64

# %% [markdown]
# ### 3.c: How many orders per quarter?
#
# Make a line plot for these.

# %%
orders_per_quarter = order_dates.groupby(pd.Grouper(freq='Q'))['OrderID'].count()
orders_per_quarter.plot()

# %% [markdown]
# ### 3.d: Which country is receiving the most orders?

# %%
# %%sql
# SELECT "ShipCountry", count(*) as count
# FROM orders
# GROUP BY "ShipCountry"
# ORDER BY count desc
# LIMIT 3;
# Out:
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 3 rows affected.
# [('Germany', 122), ('USA', 122), ('Brazil', 83)]

# %% [markdown]
# ### 3.e: Which country is receiving the least?

# %%
# %%sql
# SELECT "ShipCountry", count(*) as count
# FROM orders
# GROUP BY "ShipCountry"
# ORDER BY count
# LIMIT 3;
# Out:
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 3 rows affected.
# [('Norway', 6), ('Poland', 7), ('Portugal', 13)]

# %% [markdown]
# ### 3.f: What's the average shipping time (ShippedDate - OrderDate)?

# %%
# in 2 steps:
days_diff  = %sql SELECT "ShippedDate", "OrderDate", "ShippedDate" - "OrderDate" as daysdiff FROM orders;
days_diff.DataFrame()['daysdiff'].mean()
# Out:
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 830 rows affected.
# 8.491965389369591

# %%
# in 1 query:
# %sql SELECT avg("ShippedDate" - "OrderDate") FROM orders;
# Out:
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 1 rows affected.
# [(Decimal('8.4919653893695921'),)]

# %% [markdown]
# ### 3.g: What customer is submitting the highest number of orders?

# %%
# %%sql
# SELECT "CustomerID", count(*) as count FROM orders GROUP BY "CustomerID" LIMIT 3;
# Out:
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 3 rows affected.
# [('HUNGO', 19), ('VAFFE', 11), ('PRINI', 5)]

# %% [markdown]
# ### 3.h: What customer is generating the highest revenue (need to pd.merge with order_details)?

# %%
customer_orders = %sql SELECT "CustomerID", "OrderID" FROM orders;
order_details = %sql SELECT * FROM order_details;
customer_order_details = pd.merge(customer_orders.DataFrame(), order_details.DataFrame())
customer_order_details.head()
# Out:
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 830 rows affected.
#  * postgresql://dsi_student:***@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
# 2155 rows affected.
#   CustomerID  OrderID  ProductID  UnitPrice  Quantity  Discount
# 0      VINET    10248         11       14.0        12       0.0
# 1      VINET    10248         42        9.8        10       0.0
# 2      VINET    10248         72       34.8         5       0.0
# 3      TOMSP    10249         14       18.6         9       0.0
# 4      TOMSP    10249         51       42.4        40       0.0

# %%
customer_order_details['OrderRevenue'] = customer_order_details['UnitPrice'] * \
                                         customer_order_details['Quantity'] * \
                                         (1.0 - customer_order_details['Discount'])

# %%
customer_revenue = customer_order_details.groupby('CustomerID')['OrderRevenue'].sum().sort_values(ascending = False)
customer_revenue.head()
# Out:
# CustomerID
# QUICK    110277.3050
# ERNSH    104874.9785
# SAVEA    104361.9500
# RATTC     51097.8005
# HUNGO     49979.9050
# Name: OrderRevenue, dtype: float64

# %% [markdown]
# ### 3.i: What fraction of the revenue is generated by the top 5 customers?
#
# Compare that with the fraction represented by 5 customers over the total number of customers.

# %%
customer_revenue.head().sum() / customer_revenue.sum()
# Out:
# 0.33227543988244534

# %%
5.0 / customer_revenue.count()
# Out:
# 0.056179775280898875

# %% [markdown]
# Wow!! 5.5% of the customers generate a third of the revenue!!

# %% [markdown]
# ## Bonus: Other tables
#
# Investigate the content of other tables. In particular lookt at the `suppliers`, `shippers` and `employees` tables.
